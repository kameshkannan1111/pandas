# %%
import pandas as pd

# %%
df1 = pd.DataFrame({"ID":[1,2,3,5,9],
                   "col_1":[1,2,3,4,5],
                   "col_2":[6,7,8,9,10],
                   "col_3":[11,12,13,14,15],
                   "col_4":["apple","orange","banana","strawberry","raspberry"]})
df2 = pd.DataFrame({"ID":[1,1,3,5],
                   "col_A":[8,9,10,11],
                   "col_B":[12,13,15,17],
                   "col_4":["apple","orange","banana","kiwi"]
                   #"col_4":[1,2,3,4]
                   })

# %%
df1
# Out:
#    ID  col_1  col_2  col_3       col_4
# 0   1      1      6     11       apple
# 1   2      2      7     12      orange
# 2   3      3      8     13      banana
# 3   5      4      9     14  strawberry
# 4   9      5     10     15   raspberry

# %%
df2
# Out:
#    ID  col_A  col_B   col_4
# 0   1      8     12   apple
# 1   1      9     13  orange
# 2   3     10     15  banana
# 3   5     11     17    kiwi

# %%
inner = pd.merge(df1,df2)

# %%
inner
# Out:
#    ID  col_1  col_2  col_3   col_4  col_A  col_B
# 0   1      1      6     11   apple      8     12
# 1   3      3      8     13  banana     10     15

# %%
pd.merge(df1,df2,on="ID")
# Out:
#    ID  col_1  col_2  col_3     col_4_x  col_A  col_B col_4_y
# 0   1      1      6     11       apple      8     12   apple
# 1   1      1      6     11       apple      9     13  orange
# 2   3      3      8     13      banana     10     15  banana
# 3   5      4      9     14  strawberry     11     17    kiwi

# %%
pd.merge(df1,df2,on=["ID","col_4"])
# Out:
#    ID  col_1  col_2  col_3   col_4  col_A  col_B
# 0   1      1      6     11   apple      8     12
# 1   3      3      8     13  banana     10     15

# %%
pd.merge(df1,df2,suffixes=["_l","_r"],left_on = "col_2",right_on = "col_A")
# Out:
#    ID_l  col_1  col_2  col_3     col_4_l  ID_r  col_A  col_B col_4_r
# 0     3      3      8     13      banana     1      8     12   apple
# 1     5      4      9     14  strawberry     1      9     13  orange
# 2     9      5     10     15   raspberry     3     10     15  banana

# %%
pd.merge(df1,df2,suffixes=["_l","_r"],left_index = True,right_index = True)
# Out:
#    ID_l  col_1  col_2  col_3     col_4_l  ID_r  col_A  col_B col_4_r
# 0     1      1      6     11       apple     1      8     12   apple
# 1     2      2      7     12      orange     1      9     13  orange
# 2     3      3      8     13      banana     3     10     15  banana
# 3     5      4      9     14  strawberry     5     11     17    kiwi

# %%
#outer join
pd.merge(df1,df2,on="col_4",how="outer",suffixes=["_l","_r"])
# Out:
#    ID_l  col_1  col_2  col_3       col_4  ID_r  col_A  col_B
# 0   1.0    1.0    6.0   11.0       apple   1.0    8.0   12.0
# 1   2.0    2.0    7.0   12.0      orange   1.0    9.0   13.0
# 2   3.0    3.0    8.0   13.0      banana   3.0   10.0   15.0
# 3   5.0    4.0    9.0   14.0  strawberry   NaN    NaN    NaN
# 4   9.0    5.0   10.0   15.0   raspberry   NaN    NaN    NaN
# 5   NaN    NaN    NaN    NaN        kiwi   5.0   11.0   17.0

# %%
pd.merge(df1,df2,on="col_4",how="inner",suffixes=["_l","_r"])
# Out:
#    ID_l  col_1  col_2  col_3   col_4  ID_r  col_A  col_B
# 0     1      1      6     11   apple     1      8     12
# 1     2      2      7     12  orange     1      9     13
# 2     3      3      8     13  banana     3     10     15

# %%
pd.merge(df1,df2,on="col_4",how="left",suffixes=["_l","_r"])
# Out:
#    ID_l  col_1  col_2  col_3       col_4  ID_r  col_A  col_B
# 0     1      1      6     11       apple   1.0    8.0   12.0
# 1     2      2      7     12      orange   1.0    9.0   13.0
# 2     3      3      8     13      banana   3.0   10.0   15.0
# 3     5      4      9     14  strawberry   NaN    NaN    NaN
# 4     9      5     10     15   raspberry   NaN    NaN    NaN

# %%
pd.merge(df1,df2,on="col_4",how="right",suffixes=["_l","_r"])
# Out:
#    ID_l  col_1  col_2  col_3   col_4  ID_r  col_A  col_B
# 0   1.0    1.0    6.0   11.0   apple     1      8     12
# 1   2.0    2.0    7.0   12.0  orange     1      9     13
# 2   3.0    3.0    8.0   13.0  banana     3     10     15
# 3   NaN    NaN    NaN    NaN    kiwi     5     11     17

# %% [markdown]
# # common problems/issues/errors

# %%
pd.merge(df1,df2,on = "col_4")
# Out:
#    ID_x  col_1  col_2  col_3   col_4  ID_y  col_A  col_B
# 0     1      1      6     11   apple     1      8     12
# 1     2      2      7     12  orange     1      9     13
# 2     3      3      8     13  banana     3     10     15

# %%
pd.merge(df1,df2,on = "col_4")
# Out:
#    ID_x  col_1  col_2  col_3   col_4  ID_y  col_A  col_B
# 0     1      1      6     11   apple     1      8     12
# 1     2      2      7     12  orange     1      9     13
# 2     3      3      8     13  banana     3     10     15

# %%
pd.merge(df1,df2, on="ID" ,suffixes=["_l","_r"],left_on = "col_2",right_on = "col_A")
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Input In [234], in <cell line: 1>()
# ----> 1 pd.merge(df1,df2, on="ID" ,suffixes=["_l","_r"],left_on = "col_2",right_on = "col_A")
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
# ...

# %% [markdown]
# # df.join()

# %% [markdown]
# # *anything you can do with .join you can do with .merge

# %%
df1.join(df2,on="ID",lsuffix = "_l",rsuffix="_r")
# Out:
#    ID_l  col_1  col_2  col_3     col_4_l  ID_r  col_A  col_B col_4_r
# 0     1      1      6     11       apple   1.0    9.0   13.0  orange
# 1     2      2      7     12      orange   3.0   10.0   15.0  banana
# 2     3      3      8     13      banana   5.0   11.0   17.0    kiwi
# 3     5      4      9     14  strawberry   NaN    NaN    NaN     NaN
# 4     9      5     10     15   raspberry   NaN    NaN    NaN     NaN

# %%
df1.join(df2,on="ID",how = "inner",lsuffix = "_l",rsuffix="_r")
# Out:
#    ID  ID_l  col_1  col_2  col_3 col_4_l  ID_r  col_A  col_B col_4_r
# 0   1     1      1      6     11   apple     1      9     13  orange
# 1   2     2      2      7     12  orange     3     10     15  banana
# 2   3     3      3      8     13  banana     5     11     17    kiwi

# %%
df1.join(df2,on="ID",how = "outer",lsuffix = "_l",rsuffix="_r")
# Out:
#      ID  ID_l  col_1  col_2  col_3     col_4_l  ID_r  col_A  col_B  col_4_r
# 0.0   1   1.0    1.0    6.0   11.0       apple   1.0    9.0   13.0      2.0
# 1.0   2   2.0    2.0    7.0   12.0      orange   3.0   10.0   15.0      3.0
# 2.0   3   3.0    3.0    8.0   13.0      banana   5.0   11.0   17.0      4.0
# 3.0   5   5.0    4.0    9.0   14.0  strawberry   NaN    NaN    NaN      NaN
# 4.0   9   9.0    5.0   10.0   15.0   raspberry   NaN    NaN    NaN      NaN
# NaN   0   NaN    NaN    NaN    NaN         NaN   1.0    8.0   12.0      1.0

# %%
df1.join(df2,on="ID",how = "left",lsuffix = "_l",rsuffix="_r")
# Out:
#    ID_l  col_1  col_2  col_3     col_4_l  ID_r  col_A  col_B  col_4_r
# 0     1      1      6     11       apple   1.0    9.0   13.0      2.0
# 1     2      2      7     12      orange   3.0   10.0   15.0      3.0
# 2     3      3      8     13      banana   5.0   11.0   17.0      4.0
# 3     5      4      9     14  strawberry   NaN    NaN    NaN      NaN
# 4     9      5     10     15   raspberry   NaN    NaN    NaN      NaN

# %%
df1.join(df2,on="ID",how = "right",lsuffix = "_l",rsuffix="_r")
# Out:
#      ID  ID_l  col_1  col_2  col_3 col_4_l  ID_r  col_A  col_B  col_4_r
# NaN   0   NaN    NaN    NaN    NaN     NaN     1      8     12        1
# 0.0   1   1.0    1.0    6.0   11.0   apple     1      9     13        2
# 1.0   2   2.0    2.0    7.0   12.0  orange     3     10     15        3
# 2.0   3   3.0    3.0    8.0   13.0  banana     5     11     17        4

# %%
pd.concat([df1,df2])
# Out:
#    ID  col_1  col_2  col_3       col_4  col_A  col_B
# 0   1    1.0    6.0   11.0       apple    NaN    NaN
# 1   2    2.0    7.0   12.0      orange    NaN    NaN
# 2   3    3.0    8.0   13.0      banana    NaN    NaN
# 3   5    4.0    9.0   14.0  strawberry    NaN    NaN
# 4   9    5.0   10.0   15.0   raspberry    NaN    NaN
# 0   1    NaN    NaN    NaN       apple    8.0   12.0
# 1   1    NaN    NaN    NaN      orange    9.0   13.0
# 2   3    NaN    NaN    NaN      banana   10.0   15.0
# 3   5    NaN    NaN    NaN        kiwi   11.0   17.0

# %%
pd.concat([df1,df2],ignore_index=True)
# Out:
#    ID  col_1  col_2  col_3       col_4  col_A  col_B
# 0   1    1.0    6.0   11.0       apple    NaN    NaN
# 1   2    2.0    7.0   12.0      orange    NaN    NaN
# 2   3    3.0    8.0   13.0      banana    NaN    NaN
# 3   5    4.0    9.0   14.0  strawberry    NaN    NaN
# 4   9    5.0   10.0   15.0   raspberry    NaN    NaN
# 5   1    NaN    NaN    NaN       apple    8.0   12.0
# 6   1    NaN    NaN    NaN      orange    9.0   13.0
# 7   3    NaN    NaN    NaN      banana   10.0   15.0
# 8   5    NaN    NaN    NaN        kiwi   11.0   17.0

# %%
pd.concat([df1,df2],axis=1)
# Out:
#    ID  col_1  col_2  col_3       col_4   ID  col_A  col_B   col_4
# 0   1      1      6     11       apple  1.0    8.0   12.0   apple
# 1   2      2      7     12      orange  1.0    9.0   13.0  orange
# 2   3      3      8     13      banana  3.0   10.0   15.0  banana
# 3   5      4      9     14  strawberry  5.0   11.0   17.0    kiwi
# 4   9      5     10     15   raspberry  NaN    NaN    NaN     NaN

# %%
df1
# Out:
#    ID  col_1  col_2  col_3       col_4
# 0   1      1      6     11       apple
# 1   2      2      7     12      orange
# 2   3      3      8     13      banana
# 3   5      4      9     14  strawberry
# 4   9      5     10     15   raspberry

# %%
df2
# Out:
#    ID  col_A  col_B   col_4
# 0   1      8     12   apple
# 1   1      9     13  orange
# 2   3     10     15  banana
# 3   5     11     17    kiwi

# %%
pd.concat([df1,df2],axis=1,join="inner")
# Out:
#    ID  col_1  col_2  col_3       col_4  ID  col_A  col_B   col_4
# 0   1      1      6     11       apple   1      8     12   apple
# 1   2      2      7     12      orange   1      9     13  orange
# 2   3      3      8     13      banana   3     10     15  banana
# 3   5      4      9     14  strawberry   5     11     17    kiwi

# %%
pd.concat([df1,df2],axis=0,join="inner")
# Out:
#    ID       col_4
# 0   1       apple
# 1   2      orange
# 2   3      banana
# 3   5  strawberry
# 4   9   raspberry
# 0   1       apple
# 1   1      orange
# 2   3      banana
# 3   5        kiwi

# %% [markdown]
# # df.append()

# %%
df1.append(df2)
# Out:
# /var/folders/dz/vxq2lcnx06x8dzf96pr35w3w0000gn/T/ipykernel_1461/3062608662.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1.append(df2)
#    ID  col_1  col_2  col_3       col_4  col_A  col_B
# 0   1    1.0    6.0   11.0       apple    NaN    NaN
# 1   2    2.0    7.0   12.0      orange    NaN    NaN
# 2   3    3.0    8.0   13.0      banana    NaN    NaN
# 3   5    4.0    9.0   14.0  strawberry    NaN    NaN
# 4   9    5.0   10.0   15.0   raspberry    NaN    NaN
# 0   1    NaN    NaN    NaN       apple    8.0   12.0
# 1   1    NaN    NaN    NaN      orange    9.0   13.0
# 2   3    NaN    NaN    NaN      banana   10.0   15.0
# 3   5    NaN    NaN    NaN        kiwi   11.0   17.0

# %%
df1.append(df2,ignore_index=True)
# Out:
# /var/folders/dz/vxq2lcnx06x8dzf96pr35w3w0000gn/T/ipykernel_1461/2717680053.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1.append(df2,ignore_index=True)
#    ID  col_1  col_2  col_3       col_4  col_A  col_B
# 0   1    1.0    6.0   11.0       apple    NaN    NaN
# 1   2    2.0    7.0   12.0      orange    NaN    NaN
# 2   3    3.0    8.0   13.0      banana    NaN    NaN
# 3   5    4.0    9.0   14.0  strawberry    NaN    NaN
# 4   9    5.0   10.0   15.0   raspberry    NaN    NaN
# 5   1    NaN    NaN    NaN       apple    8.0   12.0
# 6   1    NaN    NaN    NaN      orange    9.0   13.0
# 7   3    NaN    NaN    NaN      banana   10.0   15.0
# 8   5    NaN    NaN    NaN        kiwi   11.0   17.0

# %%
row = df1.loc[3,]

# %%
row
# Out:
# ID                5
# col_1             4
# col_2             9
# col_3            14
# col_4    strawberry
# Name: 3, dtype: object

# %%
df1
# Out:
#    ID  col_1  col_2  col_3       col_4
# 0   1      1      6     11       apple
# 1   2      2      7     12      orange
# 2   3      3      8     13      banana
# 3   5      4      9     14  strawberry
# 4   9      5     10     15   raspberry

# %%
df1.append(row)
# Out:
# /var/folders/dz/vxq2lcnx06x8dzf96pr35w3w0000gn/T/ipykernel_1461/3176117447.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1.append(row)
#    ID  col_1  col_2  col_3       col_4
# 0   1      1      6     11       apple
# 1   2      2      7     12      orange
# 2   3      3      8     13      banana
# 3   5      4      9     14  strawberry
# 4   9      5     10     15   raspberry
# 3   5      4      9     14  strawberry

# %%
df1.loc[5] = [1,2,3,4,"hiii"]

# %%
df1
# Out:
#    ID  col_1  col_2  col_3       col_4
# 0   1      1      6     11       apple
# 1   2      2      7     12      orange
# 2   3      3      8     13      banana
# 3   5      4      9     14  strawberry
# 4   9      5     10     15   raspberry
# 5   1      2      3      4        hiii

# %%
import seaborn as sns

# %%
data = sns.load_dataset("titanic")

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
pd.set_option('display.max_columns',20)

# %%
pd.set_option('display.max_rows', 100)

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
data.head(7)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
# 6         0       1    male  54.0      0      0  51.8625        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# ...

# %%
data.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
data.drop(columns=['embarked', 'deck'],axis=1)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare   class    who  \
# 0           0       3    male  22.0      1      0   7.2500   Third    man
# 1           1       1  female  38.0      1      0  71.2833   First  woman
# 2           1       3  female  26.0      0      0   7.9250   Third  woman
# 3           1       1  female  35.0      1      0  53.1000   First  woman
# 4           0       3    male  35.0      0      0   8.0500   Third    man
# ..        ...     ...     ...   ...    ...    ...      ...     ...    ...
# 886         0       2    male  27.0      0      0  13.0000  Second    man
# 887         1       1  female  19.0      0      0  30.0000   First  woman
# 888         0       3  female   NaN      1      2  23.4500   Third  woman
# 889         1       1    male  26.0      0      0  30.0000   First    man
# 890         0       3    male  32.0      0      0   7.7500   Third    man
#
#      adult_male  embark_town alive  alone
# ...

# %%
data.drop(886,axis=0)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
len(data)
# Out:
# 891

# %%
data.query("pclass < sibsp")
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 16          0       3    male   2.0      4      1   29.1250        Q   Third
# 27          0       1    male  19.0      3      2  263.0000        S   First
# 50          0       3    male   7.0      4      1   39.6875        S   Third
# 59          0       3    male  11.0      5      2   46.9000        S   Third
# 68          1       3  female  17.0      4      2    7.9250        S   Third
# 71          0       3  female  16.0      5      2   46.9000        S   Third
# 88          1       1  female  23.0      3      2  263.0000        S   First
# 119         0       3  female   2.0      4      2   31.2750        S   Third
# 159         0       3    male   NaN      8      2   69.5500        S   Third
# 164         0       3    male   1.0      4      1   39.6875        S   Third
# 171         0       3    male   4.0      4      1   29.1250        Q   Third
# ...

# %%
data.iloc[:10, 0:4]
# Out:
#    survived  pclass     sex   age
# 0         0       3    male  22.0
# 1         1       1  female  38.0
# 2         1       3  female  26.0
# 3         1       1  female  35.0
# 4         0       3    male  35.0
# 5         0       3    male   NaN
# 6         0       1    male  54.0
# 7         0       3    male   2.0
# 8         1       3  female  27.0
# 9         1       2  female  14.0

# %%
data.iloc[:200,[2,6,9]]
# Out:
#         sex      fare    who
# 0      male    7.2500    man
# 1    female   71.2833  woman
# 2    female    7.9250  woman
# 3    female   53.1000  woman
# 4      male    8.0500    man
# ..      ...       ...    ...
# 195  female  146.5208  woman
# 196    male    7.7500    man
# 197    male    8.4042    man
# 198  female    7.7500  woman
# 199  female   13.0000  woman
#
# [200 rows x 3 columns]

# %%
data.loc[2:5,["sex","fare"]]
# Out:
#       sex     fare
# 2  female   7.9250
# 3  female  53.1000
# 4    male   8.0500
# 5    male   8.4583

# %%
data.age.dtypes
# Out:
# dtype('float64')

# %%
data.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
data.select_dtypes(include='object')
# Out:
#         sex embarked    who  embark_town alive
# 0      male        S    man  Southampton    no
# 1    female        C  woman    Cherbourg   yes
# 2    female        S  woman  Southampton   yes
# 3    female        S  woman  Southampton   yes
# 4      male        S    man  Southampton    no
# ..      ...      ...    ...          ...   ...
# 886    male        S    man  Southampton    no
# 887  female        S  woman  Southampton   yes
# 888  female        S  woman  Southampton    no
# 889    male        C    man    Cherbourg   yes
# 890    male        Q    man   Queenstown    no
#
# [891 rows x 5 columns]

# %%
data.select_dtypes(exclude='int64')
# Out:
#         sex   age     fare embarked   class    who  adult_male deck  \
# 0      male  22.0   7.2500        S   Third    man        True  NaN
# 1    female  38.0  71.2833        C   First  woman       False    C
# 2    female  26.0   7.9250        S   Third  woman       False  NaN
# 3    female  35.0  53.1000        S   First  woman       False    C
# 4      male  35.0   8.0500        S   Third    man        True  NaN
# ..      ...   ...      ...      ...     ...    ...         ...  ...
# 886    male  27.0  13.0000        S  Second    man        True  NaN
# 887  female  19.0  30.0000        S   First  woman       False    B
# 888  female   NaN  23.4500        S   Third  woman       False  NaN
# 889    male  26.0  30.0000        C   First    man        True    C
# 890    male  32.0   7.7500        Q   Third    man        True  NaN
#
#      embark_town alive  alone
# 0    Southampton    no  False
# 1      Cherbourg   yes  False
# 2    Southampton   yes   True
# ...

# %%
import numpy as np

# %%
random_col = np.random.randint(100, size=len(data))

# %%
data.insert(3, 'random_col', random_col)

# %%
data
# Out:
#      survived  pclass     sex  random_col   age  sibsp  parch     fare  \
# 0           0       3    male          78  22.0      1      0   7.2500
# 1           1       1  female          40  38.0      1      0  71.2833
# 2           1       3  female          68  26.0      0      0   7.9250
# 3           1       1  female          58  35.0      1      0  53.1000
# 4           0       3    male           6  35.0      0      0   8.0500
# ..        ...     ...     ...         ...   ...    ...    ...      ...
# 886         0       2    male          15  27.0      0      0  13.0000
# 887         1       1  female          39  19.0      0      0  30.0000
# 888         0       3  female          13   NaN      1      2  23.4500
# 889         1       1    male          71  26.0      0      0  30.0000
# 890         0       3    male          31  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %%
data[['pclass', 'random_col']].cumsum()
# Out:
#      pclass  random_col
# 0         3          78
# 1         4         118
# 2         7         186
# 3         8         244
# 4        11         250
# ..      ...         ...
# 886    2049       42988
# 887    2050       43027
# 888    2053       43040
# 889    2054       43111
# 890    2057       43142
#
# [891 rows x 2 columns]

# %%
data.sample(n = 200)
# Out:
#      survived  pclass     sex  random_col   age  sibsp  parch     fare  \
# 796         1       1  female          78  49.0      0      0  25.9292
# 98          1       2  female          15  34.0      0      1  23.0000
# 629         0       3    male          45   NaN      0      0   7.7333
# 283         1       3    male          48  19.0      0      0   8.0500
# 749         0       3    male          63  31.0      0      0   7.7500
# ..        ...     ...     ...         ...   ...    ...    ...      ...
# 675         0       3    male          51  18.0      0      0   7.7750
# 548         0       3    male          60  33.0      1      1  20.5250
# 314         0       2    male          26  43.0      1      1  26.2500
# 736         0       3  female          10  48.0      1      3  34.3750
# 63          0       3    male          15   4.0      3      2  27.9000
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %%
data.sample(frac = 0.10)
# Out:
#      survived  pclass     sex  random_col   age  sibsp  parch      fare  \
# 325         1       1  female          38  36.0      0      0  135.6333
# 158         0       3    male           7   NaN      0      0    8.6625
# 740         1       1    male          36   NaN      0      0   30.0000
# 543         1       2    male          97  32.0      1      0   26.0000
# 252         0       1    male          15  62.0      0      0   26.5500
# 661         0       3    male          13  40.0      0      0    7.2250
# 278         0       3    male          18   7.0      4      1   29.1250
# 720         1       2  female          40   6.0      0      1   33.0000
# 287         0       3    male           8  22.0      0      0    7.8958
# 22          1       3  female          63  15.0      0      0    8.0292
# 741         0       1    male          20  36.0      1      0   78.8500
# 30          0       1    male          82  40.0      0      0   27.7208
# ...

# %%
data['random_col'].where(data['random_col'] > 50)
# Out:
# 0       NaN
# 1      99.0
# 2      53.0
# 3      78.0
# 4       NaN
#        ...
# 886     NaN
# 887    78.0
# 888    61.0
# 889     NaN
# 890     NaN
# Name: random_col, Length: 891, dtype: float64

# %%
data['random_col'].where(data['random_col'] > 50,0)
# Out:
# 0       0
# 1      99
# 2      53
# 3      78
# 4       0
#        ..
# 886     0
# 887    78
# 888    61
# 889     0
# 890     0
# Name: random_col, Length: 891, dtype: int64

# %%
data.sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
data.sex.nunique()
# Out:
# 2

# %%
data.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# random_col     100
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
classes = ["First","Second"]
#data[data["class"].isin(classes)]

# %%
data.replace("First", 1)
# Out:
#      survived  pclass     sex  random_col   age  sibsp  parch     fare  \
# 0           0       3    male          45  22.0      1      0   7.2500
# 1           1       1  female          99  38.0      1      0  71.2833
# 2           1       3  female          53  26.0      0      0   7.9250
# 3           1       1  female          78  35.0      1      0  53.1000
# 4           0       3    male          26  35.0      0      0   8.0500
# ..        ...     ...     ...         ...   ...    ...    ...      ...
# 886         0       2    male          49  27.0      0      0  13.0000
# 887         1       1  female          78  19.0      0      0  30.0000
# 888         0       3  female          61   NaN      1      2  23.4500
# 889         1       1    male          50  26.0      0      0  30.0000
# 890         0       3    male          44  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone  \
# ...

# %%
data.replace({"First": 1,"Second":2,"Third":3})
# Out:
#      survived  pclass     sex  random_col   age  sibsp  parch     fare  \
# 0           0       3    male          45  22.0      1      0   7.2500
# 1           1       1  female          99  38.0      1      0  71.2833
# 2           1       3  female          53  26.0      0      0   7.9250
# 3           1       1  female          78  35.0      1      0  53.1000
# 4           0       3    male          26  35.0      0      0   8.0500
# ..        ...     ...     ...         ...   ...    ...    ...      ...
# 886         0       2    male          49  27.0      0      0  13.0000
# 887         1       1  female          78  19.0      0      0  30.0000
# 888         0       3  female          61   NaN      1      2  23.4500
# 889         1       1    male          50  26.0      0      0  30.0000
# 890         0       3    male          44  32.0      0      0   7.7500
#
#     embarked class    who  adult_male deck  embark_town alive  alone  \
# ...

# %%
data.rename(columns = {"random_col": "changed 1", "who": "changed 2"})
# Out:
#      survived  pclass     sex  changed 1   age  sibsp  parch     fare  \
# 0           0       3    male         45  22.0      1      0   7.2500
# 1           1       1  female         99  38.0      1      0  71.2833
# 2           1       3  female         53  26.0      0      0   7.9250
# 3           1       1  female         78  35.0      1      0  53.1000
# 4           0       3    male         26  35.0      0      0   8.0500
# ..        ...     ...     ...        ...   ...    ...    ...      ...
# 886         0       2    male         49  27.0      0      0  13.0000
# 887         1       1  female         78  19.0      0      0  30.0000
# 888         0       3  female         61   NaN      1      2  23.4500
# 889         1       1    male         50  26.0      0      0  30.0000
# 890         0       3    male         44  32.0      0      0   7.7500
#
#     embarked   class changed 2  adult_male deck  embark_town alive  alone  \
# ...

# %%
data['class'].fillna(0, inplace=True)

# %%
data
# Out:
#      survived  pclass     sex  random_col   age  sibsp  parch     fare  \
# 0           0       3    male          45  22.0      1      0   7.2500
# 1           1       1  female          99  38.0      1      0  71.2833
# 2           1       3  female          53  26.0      0      0   7.9250
# 3           1       1  female          78  35.0      1      0  53.1000
# 4           0       3    male          26  35.0      0      0   8.0500
# ..        ...     ...     ...         ...   ...    ...    ...      ...
# 886         0       2    male          49  27.0      0      0  13.0000
# 887         1       1  female          78  19.0      0      0  30.0000
# 888         0       3  female          61   NaN      1      2  23.4500
# 889         1       1    male          50  26.0      0      0  30.0000
# 890         0       3    male          44  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone  \
# ...

# %%
data['age'].fillna(data['age'].mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: age, Length: 891, dtype: float64

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data.groupby("sex")['fare'].sum()
# Out:
# sex
# female    13966.6628
# male      14727.2865
# Name: fare, dtype: float64

# %%
data.groupby(['sex', 'embarked'])['fare', 'age'].agg([np.mean, np.median])
# Out:
# /var/folders/dz/vxq2lcnx06x8dzf96pr35w3w0000gn/T/ipykernel_1461/833004882.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby(['sex', 'embarked'])['fare', 'age'].agg([np.mean, np.median])
#                       fare                  age
#                       mean    median       mean median
# sex    embarked
# female C         75.169805  56.92920  28.344262   24.0
#        Q         12.634958   7.76875  24.291667   21.5
#        S         38.740929  24.15000  27.771505   27.0
# male   C         48.262109  24.00000  32.998841   30.0
#        Q         13.838922   7.75000  30.937500   30.0
#        S         21.711996  10.50000  30.291440   28.0

# %%
data['sex'].value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
data['sex'].value_counts(ascending=True)
# Out:
# female    314
# male      577
# Name: sex, dtype: int64

# %%
pd.crosstab(data['sex'], data['class'])
# Out:
# class   First  Second  Third
# sex
# female     94      76    144
# male      122     108    347

# %%
pd.crosstab(data['sex'], data['class'], 
            margins = True,
            margins_name="Total",
            )
# Out:
# class   First  Second  Third  Total
# sex
# female     94      76    144    314
# male      122     108    347    577
# Total     216     184    491    891

# %%
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data.describe(include="all")
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# ...

# %%
data.nlargest(5, "fare")
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
# 27          0       1    male  19.0      3      2  263.0000        S  First
# 88          1       1  female  23.0      3      2  263.0000        S  First
#
#        who  adult_male deck  embark_town alive  alone
# 258  woman       False  NaN    Cherbourg   yes   True
# 679    man        True    B    Cherbourg   yes  False
# 737    man        True    B    Cherbourg   yes   True
# 27     man        True    C  Southampton    no  False
# 88   woman       False    C  Southampton   yes  False

# %%
data.nsmallest(5, "fare")
# Out:
#      survived  pclass   sex   age  sibsp  parch  fare embarked   class  who  \
# 179         0       3  male  36.0      0      0   0.0        S   Third  man
# 263         0       1  male  40.0      0      0   0.0        S   First  man
# 271         1       3  male  25.0      0      0   0.0        S   Third  man
# 277         0       2  male   NaN      0      0   0.0        S  Second  man
# 302         0       3  male  19.0      0      0   0.0        S   Third  man
#
#      adult_male deck  embark_town alive  alone
# 179        True  NaN  Southampton    no   True
# 263        True    B  Southampton    no   True
# 271        True  NaN  Southampton   yes   True
# 277        True  NaN  Southampton    no   True
# 302        True  NaN  Southampton    no   True

# %%
data["age"].isnull().sum()
# Out:
# 0

# %%
data["age"].fillna(data["age"].mean(),inplace=True)

# %%
convert_dict = {'age': int,
                'pclass': float
                }
 
data = data.astype(convert_dict)
print(data.dtypes)
# Out:
# survived          int64
# pclass          float64
# sex              object
# age               int64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df1 = pd.DataFrame({"city": ['A', 'B', 'C'],
                   "day1": [22, 25, 21],
                   'day2':[31, 12, 67],
                   'day3': [27, 20, 15],
                   'day4': [34, 37, [41, 45, 67, 90, 21]],
                   'day5': [23, 54, 36]})
df1
# Out:
#   city  day1  day2  day3                  day4  day5
# 0    A    22    31    27                    34    23
# 1    B    25    12    20                    37    54
# 2    C    21    67    15  [41, 45, 67, 90, 21]    36

# %%
df1.explode('day4').reset_index(drop=True)
# Out:
#   city  day1  day2  day3 day4  day5
# 0    A    22    31    27   34    23
# 1    B    25    12    20   37    54
# 2    C    21    67    15   41    36
# 3    C    21    67    15   45    36
# 4    C    21    67    15   67    36
# 5    C    21    67    15   90    36
# 6    C    21    67    15   21    36

# %%
convert_dict = {'A': int,
                'C': float
                }
 
df = df.astype(convert_dict)
print(df.dtypes)
